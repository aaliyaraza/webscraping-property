# %%
import pandas as pd
import urllib.request
from bs4 import BeautifulSoup

# %%
# Create an empty list to store extracted data
l = []

# %%
# Crawling through the first page with 16 listings
page = urllib.request.urlopen('https://www.engelvoelkers.com/en/search/?businessArea=residential&facets=cntry%3Ahong_kong%3B')
soup = BeautifulSoup(page, 'html.parser')
all_first = soup.find_all("div", {"class": "ev-teaser-content"})
for i in all_first:
    d = {}
    d["Place"] = i.find("div", {"class": "ev-teaser-title"}).text
    d["Price"] = i.find("div", {"class": "ev-value"}).text.replace(" HKD","").replace(".","")
    if i.find("img", {"title": "Bedrooms"}):
        d["Bedroom"] = float(i.find("img", {"title": "Bedrooms"}).find_next("span").text.replace(" ",""))
    if i.find("img", {"title": "Bathrooms"}):
        d["Bathroom"] = float(i.find("img", {"title": "Bathrooms"}).find_next("span").text.replace(" ",""))
    if i.find("img", {"title": "Saleable Area approx."}):
        d["Saleable Area"] = float(i.find("img", {"title": "Saleable Area approx."}).find_next("span").text.replace(" m²",""))
    d["Area"] = i.find("div", {"class": "ev-teaser-subtitle"}).text.split(",")[2]
    d["Region"] = i.find("div", {"class": "ev-teaser-subtitle"}).text.split(",")[1]
    l.append(d)

# %%
# All subsequent pages with 18 listings
# Note that the last page may have fewer than 18 listings, however, since we are not going to a page after that, we do no need to worry about fixing the increment in the loop
base_url = 'https://www.engelvoelkers.com/en/search/?q=&startIndex=' 
base2_url = '&businessArea=residential&sortOrder=DESC&sortField=sortPrice&pageSize=18&facets=bsnssr%3Aresidential%3Bcntry%3Ahong_kong%3Btyp%3Abuy%3B'
for page in range(16, 820, 18):
    #print(base_url+str(page)+base2_url)
    r = urllib.request.urlopen(base_url+str(page)+base2_url)
    soup = BeautifulSoup(r, 'html.parser')
    all_pages = soup.find_all("div", {"class": "ev-teaser-content"})
    for i in all_pages:
        d = {}
        d["Place"] = i.find("div", {"class": "ev-teaser-title"}).text
        d["Price"] = i.find("div", {"class": "ev-value"}).text.replace(" HKD","").replace(".","")
        if i.find("img", {"title": "Bedrooms"}):
            d["Bedroom"] = float(i.find("img", {"title": "Bedrooms"}).find_next("span").text.replace(" ",""))
        if i.find("img", {"title": "Bathrooms"}):
            d["Bathroom"] = float(i.find("img", {"title": "Bathrooms"}).find_next("span").text.replace(" ",""))
        if i.find("img", {"title": "Saleable Area approx."}):
            d["Saleable Area"] = float(i.find("img", {"title": "Saleable Area approx."}).find_next("span").text.replace(" m²",""))
        d["Area"] = i.find("div", {"class": "ev-teaser-subtitle"}).text.split(",")[2]
        d["Region"] = i.find("div", {"class": "ev-teaser-subtitle"}).text.split(",")[1]
        l.append(d)

# %%
df = pd.DataFrame(l, columns = ["Place", "Price", "Bedroom", "Bathroom", "Saleable Area", "Area", "Region" ])
# remove listings where price is '(on request)' and convert to float for mathematical calculations 
df["Price"] = pd.to_numeric(df["Price"], errors='coerce')
df = df.dropna(subset = ["Price"])
df
# Out:
#                                          Place        Price  Bedroom  \
# 0                        28 BARKER ROAD 白加道28號  680000000.0      5.0
# 1                                  Caronia 楠樺居  600000000.0      4.0
# 2                110 Repulse Bay Road 淺水灣道110號  350000000.0      4.0
# 3                                Rock Cliff 石盧  350000000.0      3.0
# 4                  56 REPULSE BAY ROAD 淺水灣道56號  350000000.0      6.0
# 5                                Bay Villas 南源  338000000.0      4.0
# 6                  6 Stanley Beach Road 赤柱灘道6號  303000000.0      4.0
# 7                       Residence Bel-air* 貝沙灣  300000000.0      4.0
# 8                           Ondina Heights 安寧台  280000000.0      4.0
# 9                       Residence Bel-air* 貝沙灣  280000000.0      4.0
# 10                            Yue Hei Yuen 裕熙園  268000000.0      4.0
# 11                        Imperial Cullinan 瓏璽  250000000.0     11.0
# 12                12-16 TAI TAM ROAD 大潭道12-16號  245000000.0      4.0
# 13                12-16 TAI TAM ROAD 大潭道12-16號  238000000.0      4.0
# 14                             The Hazelton 榛園  230000000.0      4.0
# 15                                  SEYMOUR 懿峰  228000000.0      7.0
# 16                 56 REPULSE BAY ROAD 淺水灣道56號  220000000.0      3.0
# 17                         MANDERLY GARDEN 文禮苑  210000000.0      4.0
# 18                       CLUNY PARK CLUNY PARK  206500000.0      4.0
# 19                        Flamingo Garden 飛鵝花園  200000000.0      4.0
# 20                  Kennedy Park At Central 君珀  180000000.0      6.0
# 21                       Manhattan Tower 曼赫頓大廈  178000000.0      3.0
# 22                            BAGUIO VILLA 碧瑤灣  160000000.0      6.0
# 23                              Villa Rosa 玫瑰園  155000000.0      4.0
# 24                               Le Palais 皇府灣  150000000.0      4.0
# 25                          Century Tower 世紀大廈  150000000.0      4.0
# 26                          55 Conduit Road 璈珀  150000000.0      4.0
# 27                          The Masterpiece 名鑄  148000000.0      3.0
# 28                               Twin Brook 雙溪  140000000.0      4.0
# 29     22A-22B Mount Austin Road 柯士甸山道22A-22B號  140000000.0      3.0
# ..                                         ...          ...      ...
# 789                       Yue On Building 裕安大樓    6980000.0      NaN
# 790                        Midland Centre 中源中心    6980000.0      2.0
# 791                           To Li Garden 桃李園    6950000.0      2.0
# 792                     Tai Peng Old Village -    6880000.0      2.0
# 793                          Windsor Court 衛城閣    6800000.0      1.0
# 794                           Villa Serene 兆和軒    6800000.0      1.0
# 795                     27 Sands Street 山市街27號    7000000.0      NaN
# 796                           Pan Long Wan 檳榔灣    6800000.0      2.0
# 797                   Cheung Fai Building 祥暉大廈    6500000.0      NaN
# 798                          Mainway Court 明威閣    6300000.0      2.0
# 799                     Pak Ling Building 百齡大廈    6150000.0      2.0
# 800  Tai Peng New Village Tai Peng New Village    5980000.0      3.0
# 801                      Kai Fung Building 家鳳樓    6000000.0      2.0
# 802                     Tai Hing Building 太慶大廈    5980000.0      1.0
# 803            Yung Shue Long New Village 榕樹塱村    5900000.0      2.0
# 804                       Kee On Building 祺安大廈    5880000.0      NaN
# 805                                 Lo Tik Wan    5800000.0      3.0
# 806            Yung Shue Wan Main Street 榕樹灣大灣    5500000.0      2.0
# 807                    Fook Moon Building 福滿大廈    5300000.0      1.0
# 808                   Sai Kung Town Center 西貢苑    5200000.0      1.0
# 809                    SHAN TSUI COURT 大潭道200號    4950000.0      2.0
# 810                              Panview Court    4800000.0      NaN
# 811                     Tai Peng Old Village -    4600000.0      3.0
# 812            Yung Shue Wan Main Street 榕樹灣大灣    4400000.0      2.0
# 813  Tai Peng New Village Tai Peng New Village    3880000.0      2.0
# 814                           Island Crest 縉城峰    3500000.0      NaN
# 815                                Po Wah Yuen    3300000.0      1.0
# 816                                Po Wah Yuen    2750000.0      1.0
# 817                         Caine Mansion 堅都大廈    2500000.0      NaN
# 818                            May Mansion 美華閣    1600000.0      NaN
#
#      Bathroom  Saleable Area                                  Area  \
# 0         6.5         396.70                            Peak/South
# 1         3.0         477.34                     Mid Level Central
# 2         4.0         381.00                            Peak/South
# 3         4.0         405.80                              Sai Kung
# 4         5.0         471.58         Southern District/Repulse Bay
# 5         5.0         341.88                            Peak/South
# 6         4.5         292.37                            Peak/South
# 7         3.0         367.25                               Bel-Air
# 8         4.0         268.86                            Peak/South
# 9         6.0         389.26                               Bel-Air
# 10        4.0         319.21                            Peak/South
# 11       12.0         382.95                       Olympic Station
# 12        4.0         311.23         Southern District/Repulse Bay
# 13        4.0         295.25         Southern District/Repulse Bay
# 14        2.0         245.82                            Peak/South
# 15        5.0         290.60                        Mid Level West
# 16        3.0         222.97         Southern District/Repulse Bay
# 17        4.0         325.53                            Peak/South
# 18        4.0         220.09                     Mid Level Central
# 19        4.5         274.44                              Sai Kung
# 20        6.0         276.29                     Mid Level Central
# 21        4.0         205.78                            Peak/South
# 22        5.0         257.34                            Peak/South
# 23        5.0         307.88                            Peak/South
# 24        5.0         306.77                            Peak/South
# 25        4.5         258.83                     Mid Level Central
# 26        4.0         247.59                        Mid Level West
# 27        4.0         266.17                    Tsimshatsui/Jordan
# 28        4.5         225.10                            Peak/South
# 29        3.0         206.34                            Peak/South
# ..        ...            ...                                   ...
# 789       1.0          34.47                  Wanchai/Causeway Bay
# 790       1.0          30.75          Sheung Wan/Central/Admiralty
# 791       1.0          34.56              Kennedy Town/Sai Yin Pun
# 792       1.0          65.03                          Lamma Island
# 793       1.0          24.06                        Mid Level West
# 794       1.0          27.59          Sheung Wan/Central/Admiralty
# 795       1.0          40.13              Kennedy Town/Sai Yin Pun
# 796       1.0          65.03                              Sai Kung
# 797       1.0          27.69          Sheung Wan/Central/Admiralty
# 798       1.0          33.17                      Mongkok/Yaumatei
# 799       1.0          31.87                  Wanchai/Causeway Bay
# 800       1.0          65.03                          Lamma Island
# 801       1.0          28.52              Kennedy Town/Sai Yin Pun
# 802       1.0          27.87          Sheung Wan/Central/Admiralty
# 803       1.0          65.03                          Lamma Island
# 804       1.0          25.36                        Mid Level West
# 805       1.5         130.06                          Lamma Island
# 806       1.0          65.03                          Lamma Island
# 807       1.0          20.16              Kennedy Town/Sai Yin Pun
# 808       1.0          30.29                              Sai Kung
# 809       1.0          34.75   Shau Kei Wan/Chai Wan/Island Resort
# 810       1.0          18.77              Kennedy Town/Sai Yin Pun
# 811       1.0          65.03                          Lamma Island
# 812       1.0          65.03                          Lamma Island
# 813       2.0          65.03                          Lamma Island
# 814       NaN           9.29              Kennedy Town/Sai Yin Pun
# 815       1.0          32.52                          Lamma Island
# 816       1.0          32.52                          Lamma Island
# 817       NaN           9.29                        Mid Level West
# 818       NaN           9.29           Happy Valley/Mid Level East
#
#                     Region
# 0         Hong Kong Island
# 1         Hong Kong Island
# 2         Hong Kong Island
# 3     New Territories East
# 4         Hong Kong Island
# 5         Hong Kong Island
# 6         Hong Kong Island
# 7         Hong Kong Island
# 8         Hong Kong Island
# 9         Hong Kong Island
# 10        Hong Kong Island
# 11                 Kowloon
# 12        Hong Kong Island
# 13        Hong Kong Island
# 14        Hong Kong Island
# 15        Hong Kong Island
# 16        Hong Kong Island
# 17        Hong Kong Island
# 18        Hong Kong Island
# 19    New Territories East
# 20        Hong Kong Island
# 21        Hong Kong Island
# 22        Hong Kong Island
# 23        Hong Kong Island
# 24        Hong Kong Island
# 25        Hong Kong Island
# 26        Hong Kong Island
# 27                 Kowloon
# 28        Hong Kong Island
# 29        Hong Kong Island
# ..                     ...
# 789       Hong Kong Island
# 790       Hong Kong Island
# 791       Hong Kong Island
# 792   New Territories West
# 793       Hong Kong Island
# 794       Hong Kong Island
# 795       Hong Kong Island
# 796   New Territories East
# 797       Hong Kong Island
# 798                Kowloon
# 799       Hong Kong Island
# 800   New Territories West
# 801       Hong Kong Island
# 802       Hong Kong Island
# 803   New Territories West
# 804       Hong Kong Island
# 805   New Territories West
# 806   New Territories West
# 807       Hong Kong Island
# 808   New Territories East
# 809       Hong Kong Island
# 810       Hong Kong Island
# 811   New Territories West
# 812   New Territories West
# 813   New Territories West
# 814       Hong Kong Island
# 815   New Territories West
# 816   New Territories West
# 817       Hong Kong Island
# 818       Hong Kong Island
#
# [819 rows x 7 columns]

# %%
df.to_csv("Buying_data.csv", index = False)
